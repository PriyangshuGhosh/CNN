# %% [markdown]
# DATASET LOADING AND TRANSFORMING
# since images are having data as 0--255 so transform transforms it into the range of 0-1

# %%
from torchvision import datasets , transforms

dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
# Out:
# 100%|██████████| 9.91M/9.91M [00:04<00:00, 2.17MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 101kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 959kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 743kB/s]

# %%
image,label = dataset[0]
print(image.shape)
print(label)
# Out:
# torch.Size([1, 28, 28])
# 5

# %% [markdown]
# Initializing the data loader

# %%
from torch.utils.data import DataLoader
loader = DataLoader(dataset,batch_size=32,shuffle=True)

# %% [markdown]
# A typical Batch

# %%
images,labels = next(iter(loader))
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 1, 28, 28])
# torch.Size([32])
